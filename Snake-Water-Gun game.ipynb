# %%
# 1 for stone  -1 for water  0 for gun
import random

computer = random.choice([1,-1,0])
print("computer choice:", computer)
user = int(input("enter your choice (1 stone, -1 water, 0 gun): "))

if (computer==1 and user==-1):
    print("computer win")

elif (computer==1 and user==0):
    print("computer win")

elif (computer==1 and user==1):
    print("match draw")

elif (user==1 and computer==-1):
    print("user win")

elif (user==1 and computer==0):
    print("user win")

elif (computer==-1 and user==-1):
    print("match draw")

elif (computer==-1 and user==0):
    print("user win")

elif (computer==0 and user==0):
    print("match draw")

elif (computer==0 and user==1):
    print("computer win")

elif (computer==0 and user==-1):
    print("computer win")
# Out:
# computer choice: 0
# enter your choice (1 stone, -1 water, 0 gun):  1
# user win
