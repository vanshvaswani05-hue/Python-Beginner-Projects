# %%
import random
import string
def genetate_password(length):
    chars=string.ascii_letters + string.digits + string.punctuation
    # length=int(input("enter a length for password"))
    password=""
    for i in range(length):
        password= password+random.choice(chars)
    return password

genetate_password(10)
# Out:
# '^Kq]9;Gk2$'

# %%
import random
pass_length=int(input("enter a number that define password length"))
st="!@#$%^&*()_+=-0987654321qwertyuioplkjhgfdsazxcvbnmQWERTYUIOPLKJHGFDSAZXCVBNM"
password=""
for i in range(pass_length):
    password=password+random.choice(st)
print(password)
# Out:
# enter a number that define password length 5
# 2XTqw
