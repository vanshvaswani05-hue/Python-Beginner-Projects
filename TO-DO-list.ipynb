# %%
tasks = []

while True:
    print("\n--- TO DO LIST ---")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        task = input("Enter task: ")
        tasks.append(task)
        print("Task added successfully!")

    elif choice == "2":
        if len(tasks) == 0:
            print("No tasks available.")
        else:
            print("\nYour Tasks:")
            for task in tasks:
                print("-", task)

    elif choice == "3":
        if len(tasks) == 0:
            print("No tasks to remove.")
        else:
            task_name = input("Enter task name to remove: ")

            if task_name in tasks:
                tasks.remove(task_name)
                print("Task removed successfully!")
            else:
                print("Task not found!")

    elif choice == "4":
        print("Goodbye!")
        break

    else:
        print("Invalid choice!")
# Out:
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  1
# Enter task:  gym
# Task added successfully!
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  2
# Your Tasks:
# - gym
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  1
# Enter task:  python
# Task added successfully!
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  1
# Enter task:  video editing
# Task added successfully!
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  1
# Enter task:  dancing
# Task added successfully!
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  3
# Enter task name to remove:  dancing
# Task removed successfully!
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  hello
# Invalid choice!
#
# --- TO DO LIST ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice:  4
# Goodbye!
